# %%
import pandas as pd

# %%
df = pd.read_csv("data/Bangladesh_property_prices.csv")

# %%
df
# Out:
#       Unnamed: 0.1  Unnamed: 0                                 Location  \
# 0                0         0.0                 Sector 10, Uttara, Dhaka
# 1                1         1.0                Section 11, Mirpur, Dhaka
# 2                2         2.0           Chowdhuripara, Khilgaon, Dhaka
# 3                3         3.0                 Road No 4, Banani, Dhaka
# 4                4         4.0  South Banasree Project, Banasree, Dhaka
# ...            ...         ...                                      ...
# 4699          4699      4747.0            Middle Monipur, Mirpur, Dhaka
# 4700          4700      4748.0            Middle Monipur, Mirpur, Dhaka
# 4701          4701      4749.0            Middle Monipur, Mirpur, Dhaka
# 4702          4702      4750.0            Middle Monipur, Mirpur, Dhaka
# 4703          4703      4751.0            Middle Monipur, Mirpur, Dhaka
#
#          Price       Type  No. Beds  No. Baths    Area  Latitude  Longitude  \
# ...
